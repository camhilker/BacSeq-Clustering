# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### If url is unavailable data is also available from HMP/T2D data portal, downloaded as metadata file for each patient ID listed below

# %%
patient_data = pd.read_html("http://hmp2-data.stanford.edu/script.php?table=subject")
patient_data = pd.DataFrame(patient_data[0])
patient_data = patient_data.rename(columns={0:'SubjectID', 1:'Study', 2:'Race', 3:'Sex', 4:'Age', 5:'BMI', 6:'SSPG', 7:'IR_IS_classification'})

# %%
patient_data
# Out:
#     SubjectID          Study     Race Sex    Age    BMI    SSPG  \
# 0     ZIS22OE            HMP        C   F    NaN    NaN     NaN
# 1     ZJBOZ2X       Exercise        C   F  65.30  19.82     NaN
# 2     ZJOSZHK            HMP        C   M  41.43  19.42     NaN
# 3     ZJTKAE3            HMP        C   F  58.65  31.24  162.00
# 4     ZJXC41N  HMP, Exercise        B   F  49.69  28.24   75.00
# 5     ZK01UI6            HMP        A   M  57.78    NaN     NaN
# 6     ZK112BX  HMP, Exercise        A   F  57.72  28.89  234.00
# 7     ZK4CK8Y  HMP, Exercise        C   F  50.02  26.94   40.00
# 8     ZKFV71L  HMP, Exercise        B   F  66.08  32.54   65.00
# 9     ZKVR426            HMP        C   F  61.95  30.59  174.00
# 10    ZL63I8R  HMP, Exercise        C   M  62.88  32.94  220.00
# 11    ZL9BTWF  HMP, Exercise        C   M  64.56  26.69   99.00
# 12    ZLGD9M0            HMP        C   M  67.90  29.53   62.00
# 13    ZLPRB8E            HMP        B   F  50.90  26.86   70.00
# 14    ZLPZS0H            HMP        A   M  51.13  29.31  175.00
# 15    ZLTUJTN  HMP, Exercise        C   M  60.71  34.15  235.00
# 16    ZLYEM2C            HMP        A   M  38.80  22.51   92.00
# 17    ZLZNCLZ  HMP, Exercise        C   M  54.74  27.33  130.00
# 18    ZLZQMEV  HMP, Exercise        H   F  61.00  29.99  221.00
# 19    ZM7JY3G  HMP, Exercise        A   M  60.18  26.00  160.00
# 20    ZM8YXDM            HMP        C   M  45.43  26.71  212.13
# 21    ZMBH10Z            HMP        B   F  54.16  31.28  117.00
# 22    ZMBVNFM  HMP, Exercise        A   M  59.25  23.82   87.00
# 23    ZMGT937            HMP        A   M  33.79  26.44     NaN
# 24    ZMS5W76            HMP  unknown   F  49.97  32.73  224.00
# 25    ZN0JE53            HMP        B   M  66.81  33.32  148.00
# 26    ZN3TBJM  HMP, Exercise        C   F  67.47  30.18  133.50
# 27    ZN9TKCJ  HMP, Exercise        C   F  46.04  25.26     NaN
# 28    ZN9YTFN            HMP        H   F  60.18  32.21  140.00
# 29    ZNDMXI3            HMP        A   F  44.81  34.49  184.00
# ..        ...            ...      ...  ..    ...    ...     ...
# 77    ZUHT69X            HMP        C   M  32.33  24.05     NaN
# 78    ZUL3S6O  HMP, Exercise        C   M  56.73  24.66  100.50
# 79    ZUPAQVU  HMP, Exercise        C   M  58.19  27.59  220.00
# 80    ZV14SIB            HMP        C   M  60.50  25.19   58.00
# 81    ZV1ZA6Z            HMP        C   M  50.53  26.17     NaN
# 82    ZVBQY1N  HMP, Exercise        C   M  57.04  28.68  250.00
# 83    ZVC4YUG            HMP        A   F  47.52  27.49  217.80
# 84    ZVGW5FI            HMP        A   F  50.98  25.72  110.88
# 85    ZVM4N7A  HMP, Exercise        C   F  51.58  28.81  190.00
# 86    ZVNCGHM  HMP, Exercise        C   M  44.41  24.01   67.13
# 87    ZVTCAK9            HMP        C   F  54.36  29.25   51.00
# 88    ZW61YGW  HMP, Exercise        C   M  55.86  28.63  178.75
# 89    ZWCZHHY  HMP, Exercise        A   M  67.09  28.40  174.00
# 90    ZWFDEY0  HMP, Exercise        A   F  62.92  30.79  257.50
# 91    ZWHMV5E            HMP        C   F  62.80  33.96  191.00
# 92    ZWLGEWL            HMP        B   F  63.26  31.41  274.00
# 93    ZX52KVK            HMP        C   F  60.60  27.04  188.00
# 94    ZXHCGKV            HMP        A   F  31.37  20.25     NaN
# 95    ZXKBAO5            HMP        C   M  52.25  27.52     NaN
# 96    ZXSDNAK            HMP        H   F  53.72  29.49     NaN
# 97    ZXSO14L            HMP        C   F  36.57    NaN   65.00
# 98    ZY1ZKJY            HMP        C   F  60.34  33.33  119.00
# 99    ZY39SN0            HMP        C   F  56.26  35.26     NaN
# 100   ZY7IW45  HMP, Exercise        C   F  69.00  36.36  276.00
# 101   ZY9XQJP            HMP        C   M  63.45  29.31  151.00
# 102   ZYHHR4Z  HMP, Exercise        C   F  43.99  26.47     NaN
# 103   ZYKZ9HQ            HMP  unknown   F  55.62  29.94     NaN
# 104   ZYLJ7R7            HMP        A   F  40.97  23.45     NaN
# 105   ZYU89T9            HMP        C   F  60.19  29.83     NaN
# 106   ZYXQKWY            HMP        C   F  50.70  32.59  158.50
#
#     IR_IS_classification
# 0                Unknown
# 1                Unknown
# 2                Unknown
# 3                     IR
# 4                     IS
# 5                Unknown
# 6                     IR
# 7                     IS
# 8                     IS
# 9                     IR
# 10                    IR
# 11                    IS
# 12                    IS
# 13                    IS
# 14                    IR
# 15                    IR
# 16                    IS
# 17                    IS
# 18                    IR
# 19                    IR
# 20                    IR
# 21                    IS
# 22                    IS
# 23               Unknown
# 24                    IR
# 25                    IS
# 26                    IS
# 27               Unknown
# 28                    IS
# 29                    IR
# ..                   ...
# 77               Unknown
# 78                    IS
# 79                    IR
# 80                    IS
# 81               Unknown
# 82                    IR
# 83                    IR
# 84                    IS
# 85                    IR
# 86                    IS
# 87                    IS
# 88                    IR
# 89                    IR
# 90                    IR
# 91                    IR
# 92                    IR
# 93                    IR
# 94               Unknown
# 95               Unknown
# 96               Unknown
# 97                    IS
# 98                    IS
# 99               Unknown
# 100                   IR
# 101                   IR
# 102              Unknown
# 103              Unknown
# 104              Unknown
# 105              Unknown
# 106                   IR
#
# [107 rows x 8 columns]

# %% [markdown]
# ### This section adds results from individual patient clustering done on 5 clusters, not included in final analysis of results

# %%
female = pd.DataFrame(np.array([[8221, 9301, 2300, 8004, 1553], [7541, 2688, 6529, 4827, 6744], 
                       [11689, 2994, 5769, 1680, 353], [2608, 1738, 3335, 3886, 2254]]))

obese_f = pd.DataFrame(np.array([[5347, 5457, 2050, 2094, 1451], [4253, 3916, 7389, 5066, 7425], 
                                [8237, 7323, 4157, 5953, 4393], [6197, 6958, 8856, 2353, 8817]]))

non_f = pd.DataFrame(np.array([[3465, 3393, 3364, 4029, 2042], [2910, 4990, 2221, 1812, 4974],
                               [4220, 4022, 3111, 565, 3323], [7885, 1541, 7416, 3185, 1303]]))

male = pd.DataFrame(np.array([[8037, 6233, 3503, 4034, 3193],[2346, 2077, 5607, 10518, 4452],
                                [6370, 3116, 10466, 3103, 1945],[6047, 2258, 6191, 7480, 3024]]))

race = pd.DataFrame(np.array([[4600, 2048, 1932, 5491, 4144],[6767, 6006, 1326, 3763, 1339],
                                [6088, 7673, 2193, 553, 3493],[5419, 4044, 5818, 806, 3330]]))

# %%
full_data = pd.concat([female, obese_f, non_f, male, race], axis=0)
full_data = full_data.rename({0:'cluster 1', 1:'cluster 2', 2:'cluster 3', 3:'cluster 4', 4:'cluster 5'}, axis=1)
full_data['SubjectID'] = ['ZY7IW45','ZPEL6L3','ZWHMV5E','ZRLZ98T','ZPXU188','ZYXQKWY','ZQNZSQF','ZY39SN0','ZUF48YS','ZYHHR4Z','ZQMVU4Q','ZK4CK8Y','ZOZOW1T','ZTTL3YH','ZUL3S6O','ZTXY83G','ZN9YTFN','ZLZQMEV','ZLPZS0H','ZLYEM2C']

# %%
viz_data = full_data.join(patient_data.set_index('SubjectID'), on='SubjectID').reset_index().drop('index', axis=1)

# %%
viz_data = viz_data.drop('SSPG', axis=1)

# %%
c1_sp = ['NA','NA', 'Bacteroides', 'NA', 'Dysosmobacter welbionis/Oscillospiraceae', 'Bacteroides', 'NA', 'NA', 'NA', 'Ruminococcus', 'Bacteroides', 'NA', 'Roseburia', 'Bacteroides', 'NA', 'NA', 'NA', 'NA', 'Lachnospiraceae', 'Bacteroides']
c2_sp = ['Bacteroides','NA', 'Ruminococcus', 'Ruminococcus', 'NA', 'Faecalibacterium prausnitzii', 'NA', 'NA', 'Bacteroides', 'NA', 'Clostridium', 'NA', 'NA', 'Bacteroides', 'NA', 'NA', 'Bacteroides uniformis', 'Faecalibacterium', 'Ruminococcus faecis', 'NA']
c3_sp = ['NA','Bacteroides', 'NA', 'Firmicutes', 'NA', 'Bacteroides', 'Bacteroides', 'Bacteroides', 'NA', 'Alistipes putredinis', 'Flavonifractor plautii', 'NA', 'NA', 'Bacteroides', 'NA', 'Phascolarctobacterium faecium', 'Firmicutes', 'NA', 'NA', 'NA']
c4_sp = ['Eubacterium','NA', 'Roseburia intestinalis', 'Alistipes/Rikenellaceae', 'NA', 'NA', 'NA', 'NA', 'Bacteroides', 'Ruthenibacterium lactatiformans', 'Akkermansia muciniphila', 'NA', 'NA', 'NA', 'Bacteroides', 'NA', 'NA', 'Ruminococcus', 'Anaerostipes hadrus/Eubacterium', 'Prevotellamassilia timonensis']
c5_sp = ['Alistipes putredinis','NA', 'Alistipes putredinis', 'Alistipes shahii', 'NA', 'Bacteroides', 'Blautia', 'Clostridium/Lachnospiraceae', 'Ruminococcus', 'Bacteroides', 'Bacteroides uniformis', 'NA', 'Bacteroides', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Eubacterium']

# %%
viz_data['C1 species'] = c1_sp
viz_data['C2 species'] = c2_sp
viz_data['C3 species'] = c3_sp
viz_data['C4 species'] = c4_sp
viz_data['C5 species'] = c5_sp

# %%
viz_data.sort_values(by='IR_IS_classification')
# Out:
#     cluster 1  cluster 2  cluster 3  cluster 4  cluster 5 SubjectID  \
# 0        8221       9301       2300       8004       1553   ZY7IW45
# 17       6767       6006       1326       3763       1339   ZLZQMEV
# 2       11689       2994       5769       1680        353   ZWHMV5E
# 15       6047       2258       6191       7480       3024   ZTXY83G
# 5        4253       3916       7389       5066       7425   ZYXQKWY
# 13       2346       2077       5607      10518       4452   ZTTL3YH
# 18       6088       7673       2193        553       3493   ZLPZS0H
# 10       4220       4022       3111        565       3323   ZQMVU4Q
# 16       4600       2048       1932       5491       4144   ZN9YTFN
# 14       6370       3116      10466       3103       1945   ZUL3S6O
# 12       8037       6233       3503       4034       3193   ZOZOW1T
# 19       5419       4044       5818        806       3330   ZLYEM2C
# 3        2608       1738       3335       3886       2254   ZRLZ98T
# 1        7541       2688       6529       4827       6744   ZPEL6L3
# 11       7885       1541       7416       3185       1303   ZK4CK8Y
# 8        3465       3393       3364       4029       2042   ZUF48YS
# 7        6197       6958       8856       2353       8817   ZY39SN0
# 6        8237       7323       4157       5953       4393   ZQNZSQF
# 4        5347       5457       2050       2094       1451   ZPXU188
# 9        2910       4990       2221       1812       4974   ZYHHR4Z
#
#             Study Race Sex    Age    BMI IR_IS_classification  \
# 0   HMP, Exercise    C   F  69.00  36.36                   IR
# 17  HMP, Exercise    H   F  61.00  29.99                   IR
# 2             HMP    C   F  62.80  33.96                   IR
# 15            HMP    C   M  54.37  33.46                   IR
# 5             HMP    C   F  50.70  32.59                   IR
# 13            HMP    C   M  45.43  33.30                   IR
# 18            HMP    A   M  51.13  29.31                   IR
# 10            HMP    C   F  52.94  23.31                   IR
# 16            HMP    H   F  60.18  32.21                   IS
# 14  HMP, Exercise    C   M  56.73  24.66                   IS
# 12  HMP, Exercise    C   M  59.48  21.47                   IS
# 19            HMP    A   M  38.80  22.51                   IS
# 3             HMP    C   F  56.13  24.54                   IS
# 1   HMP, Exercise    C   F  52.33  24.44                   IS
# 11  HMP, Exercise    C   F  50.02  26.94                   IS
# 8             HMP    C   F  69.44  26.04              Unknown
# 7             HMP    C   F  56.26  35.26              Unknown
# 6             HMP    C   F  41.65  40.83              Unknown
# 4             HMP    C   F  60.95  36.64              Unknown
# 9   HMP, Exercise    C   F  43.99  26.47              Unknown
#
#                                   C1 species                    C2 species  \
# 0                                         NA                   Bacteroides
# 17                                        NA              Faecalibacterium
# 2                                Bacteroides                  Ruminococcus
# 15                                        NA                            NA
# 5                                Bacteroides  Faecalibacterium prausnitzii
# 13                               Bacteroides                   Bacteroides
# 18                           Lachnospiraceae           Ruminococcus faecis
# 10                               Bacteroides                   Clostridium
# 16                                        NA         Bacteroides uniformis
# 14                                        NA                            NA
# 12                                 Roseburia                            NA
# 19                               Bacteroides                            NA
# 3                                         NA                  Ruminococcus
# 1                                         NA                            NA
# 11                                        NA                            NA
# 8                                         NA                   Bacteroides
# 7                                         NA                            NA
# 6                                         NA                            NA
# 4   Dysosmobacter welbionis/Oscillospiraceae                            NA
# 9                               Ruminococcus                            NA
#
#                        C3 species                       C4 species  \
# 0                              NA                      Eubacterium
# 17                             NA                     Ruminococcus
# 2                              NA           Roseburia intestinalis
# 15  Phascolarctobacterium faecium                               NA
# 5                     Bacteroides                               NA
# 13                    Bacteroides                               NA
# 18                             NA  Anaerostipes hadrus/Eubacterium
# 10         Flavonifractor plautii          Akkermansia muciniphila
# 16                     Firmicutes                               NA
# 14                             NA                      Bacteroides
# 12                             NA                               NA
# 19                             NA    Prevotellamassilia timonensis
# 3                      Firmicutes          Alistipes/Rikenellaceae
# 1                     Bacteroides                               NA
# 11                             NA                               NA
# 8                              NA                      Bacteroides
# 7                     Bacteroides                               NA
# 6                     Bacteroides                               NA
# 4                              NA                               NA
# 9            Alistipes putredinis  Ruthenibacterium lactatiformans
#
#                      C5 species
# 0          Alistipes putredinis
# 17                           NA
# 2          Alistipes putredinis
# 15                           NA
# 5                   Bacteroides
# 13                           NA
# 18                           NA
# 10        Bacteroides uniformis
# 16                           NA
# 14                           NA
# 12                  Bacteroides
# 19                  Eubacterium
# 3              Alistipes shahii
# 1                            NA
# 11                           NA
# 8                  Ruminococcus
# 7   Clostridium/Lachnospiraceae
# 6                       Blautia
# 4                            NA
# 9                   Bacteroides

# %% [markdown]
# ### Creates file that does not include cluster information, attempted to use for QIIME analysis but was not the correct format

# %%
qiime_metadata = viz_data.drop(['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4', 'cluster 5', 'Study', 'C5 species', 'C1 species', 'C2 species', 'C3 species', 'C4 species'], axis=1)

# %%
qiime_metadata.to_csv('qiimemetadata.tsv', sep='\t', index=False)
